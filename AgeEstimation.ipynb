# %%
import cv2
import math
import argparse

#detect the face 
#hight and wedth of the photo and the frame 
def highlightFace(net, frame, conf_threshold=0.7):
    frameOpencvDnn=frame.copy()
    frameHeight=frameOpencvDnn.shape[0]
    frameWidth=frameOpencvDnn.shape[1]
#processing existed or downloaded photo and turn it to dnn   
    blob=cv2.dnn.blobFromImage(frameOpencvDnn, 1.0, (300, 300), [104, 117, 123], True, False)
#Load the input data for photo
    net.setInput(blob)
#
    detections=net.forward()
#store the photo cordinates value  
    faceBoxes=[]
#putting a frame around the face 
    for i in range(detections.shape[2]):
        confidence=detections[0,0,i,2]
        if confidence>conf_threshold:
            x1=int(detections[0,0,i,3]*frameWidth)
            y1=int(detections[0,0,i,4]*frameHeight)
            x2=int(detections[0,0,i,5]*frameWidth)
            y2=int(detections[0,0,i,6]*frameHeight)
            faceBoxes.append([x1,y1,x2,y2])
#properties of the frame of the face (wedth, hight,color,etc)       
            cv2.rectangle(frameOpencvDnn, (x1,y1), (x2,y2), (0,255,0), int(round(frameHeight/150)), 8)
    return frameOpencvDnn,faceBoxes

#transforming and distributing the information
parser=argparse.ArgumentParser()
parser.add_argument('execute.png')
args=parser.parse_args(parser)

#select the using model for detecting age and gender 
faceProto="opencv_face_detector.pbtxt"
faceModel="opencv_face_detector_uint8.pb"
ageProto="age_deploy.prototxt"
ageModel="age_net.caffemodel"
genderProto="gender_deploy.prototxt"
genderModel="gender_net.caffemodel"

#the list of age and gender used
MODEL_MEAN_VALUES=(78.4263377603, 87.7689143744, 114.895847746)
ageList=['(0-2)', '(4-6)', '(8-14)', '(16-20)', '(22-35)', '(38-43)', '(48-53)', '(60-100)']
genderList=['Male','Female']

#downloading face rec. , deffrentiate depending on age and gender
faceNet=cv2.dnn.readNet(faceModel,faceProto)
ageNet=cv2.dnn.readNet(ageModel,ageProto)
genderNet=cv2.dnn.readNet(genderModel,genderProto)

#openning the camera (open a video file or the camera stream)
video=cv2.VideoCapture(args.image if args.image else 0)
padding=20
#always do this loop if there is no key
while cv2.waitKey(1)<0:
    #reading the video frame
    hasFrame,frame=video.read()
    if not hasFrame:
        cv2.waitKey()
        break

#move the photo has been rec. to resultingImg , face cordinates to faceBoxes
    resultImg,faceBoxes=highlightFace(faceNet,frame)
    if not faceBoxes:
        print("No face detected")

#customize face cordinates
#select the minimum area that contain the face photo 
    for faceBox in faceBoxes:
        face=frame[max(0,faceBox[1]-padding):
                   min(faceBox[3]+padding,frame.shape[0]-1),max(0,faceBox[0]-padding)
                   :min(faceBox[2]+padding, frame.shape[1]-1)]
            
        blob=cv2.dnn.blobFromImage(face, 1.0, (227,227), MODEL_MEAN_VALUES, swapRB=False)
        
        #select the opposite gender in the gender list and put it in the gender box
        genderNet.setInput(blob)
        genderPreds=genderNet.forward()
        gender=genderList[genderPreds[0].argmax()]
        print(f'Gender: {gender}')
        #select the opposite age in the age list and put it in the age box
        ageNet.setInput(blob)
        agePreds=ageNet.forward()
        age=ageList[agePreds[0].argmax()]
        print(f'Age: {age[1:-1]} years')

        #properties of the typing line(wedth, hight,color,etc)
        cv2.putText(resultImg, f'{gender}, {age}', (faceBox[0], faceBox[1]-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,255,255), 2, cv2.LINE_AA)
        #showing the final result and the output
        cv2.imshow("Detecting age and gender", resultImg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-e4d4b6307804> in <module>
#      33 parser=argparse.ArgumentParser()
#      34 parser.add_argument('execute.png')
# ---> 35 args=parser.parse_args(parser)
#      36
#      37 #select the using model for detecting age and gender
#
# ~\Anaconda3\lib\argparse.py in parse_args(self, args, namespace)
#    1747     # =====================================
#    1748     def parse_args(self, args=None, namespace=None):
# -> 1749         args, argv = self.parse_known_args(args, namespace)
#    1750         if argv:
#    1751             msg = _('unrecognized arguments: %s')
#
# ~\Anaconda3\lib\argparse.py in parse_known_args(self, args, namespace)
#    1759         else:
#    1760             # make sure that args are mutable
# -> 1761             args = list(args)
#    1762
# ...

# %%
import cv2
import math
import argparse

#detect the face 
#hight and wedth of the photo and the frame 
def highlightFace(net, frame, conf_threshold=0.7):
    frameOpencvDnn=frame.copy()
    frameHeight=frameOpencvDnn.shape[0]
    frameWidth=frameOpencvDnn.shape[1]
#processing existed or downloaded photo and turn it to dnn   
    blob=cv2.dnn.blobFromImage(frameOpencvDnn, 1.0, (300, 300), [104, 117, 123], True, False)
#Load the input data for photo
    net.setInput(blob)
#
    detections=net.forward()
#store the photo cordinates value  
    faceBoxes=[]
#putting a frame around the face 
    for i in range(detections.shape[2]):
        confidence=detections[0,0,i,2]
        if confidence>conf_threshold:
            x1=int(detections[0,0,i,3]*frameWidth)
            y1=int(detections[0,0,i,4]*frameHeight)
            x2=int(detections[0,0,i,5]*frameWidth)
            y2=int(detections[0,0,i,6]*frameHeight)
            faceBoxes.append([x1,y1,x2,y2])
#properties of the frame of the face (wedth, hight,color,etc)       
            cv2.rectangle(frameOpencvDnn, (x1,y1), (x2,y2), (0,255,0), int(round(frameHeight/150)), 8)
    return frameOpencvDnn,faceBoxes

#transforming and distributing the information
parser=argparse.ArgumentParser()
parser.add_argument('--image')
args=parser.parse_args()

#select the using model for detecting age and gender 
faceProto="opencv_face_detector.pbtxt"
faceModel="opencv_face_detector_uint8.pb"
ageProto="age_deploy.prototxt"
ageModel="age_net.caffemodel"
genderProto="gender_deploy.prototxt"
genderModel="gender_net.caffemodel"

#the list of age and gender used
MODEL_MEAN_VALUES=(78.4263377603, 87.7689143744, 114.895847746)
ageList=['(0-2)', '(4-6)', '(8-14)', '(16-20)', '(22-35)', '(38-43)', '(48-53)', '(60-100)']
genderList=['Male','Female']

#downloading face rec. , deffrentiate depending on age and gender
faceNet=cv2.dnn.readNet(faceModel,faceProto)
ageNet=cv2.dnn.readNet(ageModel,ageProto)
genderNet=cv2.dnn.readNet(genderModel,genderProto)

#openning the camera (open a video file or the camera stream)
video=cv2.VideoCapture(args.image if args.image else 0)
padding=20
#always do this loop if there is no key
while cv2.waitKey(1)<0:
    #reading the video frame
    hasFrame,frame=video.read()
    if not hasFrame:
        cv2.waitKey()
        break

#move the photo has been rec. to resultingImg , face cordinates to faceBoxes
    resultImg,faceBoxes=highlightFace(faceNet,frame)
    if not faceBoxes:
        print("No face detected")

#customize face cordinates
#select the minimum area that contain the face photo 
    for faceBox in faceBoxes:
        face=frame[max(0,faceBox[1]-padding):
                   min(faceBox[3]+padding,frame.shape[0]-1),max(0,faceBox[0]-padding)
                   :min(faceBox[2]+padding, frame.shape[1]-1)]
            
        blob=cv2.dnn.blobFromImage(face, 1.0, (227,227), MODEL_MEAN_VALUES, swapRB=False)
        
        #select the opposite gender in the gender list and put it in the gender box
        genderNet.setInput(blob)
        genderPreds=genderNet.forward()
        gender=genderList[genderPreds[0].argmax()]
        print(f'Gender: {gender}')
        #select the opposite age in the age list and put it in the age box
        ageNet.setInput(blob)
        agePreds=ageNet.forward()
        age=ageList[agePreds[0].argmax()]
        print(f'Age: {age[1:-1]} years')

        #properties of the typing line(wedth, hight,color,etc)
        cv2.putText(resultImg, f'{gender}, {age}', (faceBox[0], faceBox[1]-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,255,255), 2, cv2.LINE_AA)
        #showing the final result and the output
        cv2.imshow("Detecting age and gender", resultImg)
# Out:
# usage: ipykernel_launcher.py [-h] execute.png
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
